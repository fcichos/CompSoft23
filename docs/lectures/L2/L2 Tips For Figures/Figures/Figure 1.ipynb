# %%
import matplotlib as mpl
import matplotlib.font_manager as font_manager
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Creating a figure, which just looks nice on the screen

# %%
plt.rcParams.update({'font.size': 16,
                     'lines.linewidth': 1,
                     'lines.markersize': 10,
                     'axes.labelsize': 10,
                     'xtick.labelsize' : 14,
                     'ytick.labelsize' : 14,
                     'xtick.top' : True,
                     'xtick.direction' : 'in',
                     'ytick.right' : True,
                     'ytick.direction' : 'in',}) 

# %config InlineBackend.figure_format = 'retina'

# %%
fig=plt.figure(figsize=(10,8))
x=np.linspace(0,np.pi*4,200)
plt.plot(x,np.sin(x),color='k')
plt.xlabel(r"angle $\theta$ in [rad]")
plt.ylabel(r"$\sin(\theta)$")
plt.savefig("../Figures/figure 1.pdf",bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ### Creating a figure, which looks good in paper and on screen

# %%
plt.rcParams.update({'font.size': 10,
                     'lines.linewidth': 1,
                     'lines.markersize': 10,
                     'axes.labelsize': 10,
                     'xtick.labelsize' : 8,
                     'ytick.labelsize' : 8,
                     'xtick.top' : True,
                     'xtick.direction' : 'in',
                     'ytick.right' : True,
                     'ytick.direction' : 'in',})

# %%
plt.figure(figsize=(3,2), dpi=150)
x=np.linspace(0,np.pi*4,200)
plt.plot(x,np.sin(x),color='k')
plt.xlabel(r"angle $\theta$ in [rad]")
plt.ylabel(r"$\sin(\theta)$")
plt.savefig("../Figures/figure 1.pdf",bbox_inches = 'tight')
plt.show()
